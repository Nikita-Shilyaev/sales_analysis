# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('sales_data_sample.csv', encoding='ISO-8859-1')

# %%
df.sort_values('orderdate').head()
# Out:
#       ordernumber  quantityordered  priceeach  orderlinenumber    sales  \
# 578         10100               30     171.70                3  5151.00
# 680         10100               50      67.80                2  3390.00
# 1267        10100               22      86.51                4  1903.22
# 2024        10100               49      34.47                1  1689.03
# 1539        10101               45      31.20                3  1404.00
#
#       orderdate   status  qtr_id  month_id  year_id   productline  msrp  \
# 578  2003-01-06  Shipped       1         1     2003  Vintage Cars   170
# 680  2003-01-06  Shipped       1         1     2003  Vintage Cars    60
# 1267 2003-01-06  Shipped       1         1     2003  Vintage Cars    92
# 2024 2003-01-06  Shipped       1         1     2003  Vintage Cars    41
# 1539 2003-01-09  Shipped       1         1     2003  Vintage Cars    33
#
#      productcode                  customername              phone  \
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df['orderdate'] = pd.to_datetime(df['orderdate'], dayfirst=True)

# %%
df['priceeach'] = df['sales'] / df['quantityordered']

# %%
df.drop(columns=df.columns[[13, 14, 22, 23]], inplace=True)

# %%
df.to_csv('C:/Users/Никита/my_projects/2. Sales/processed/Sales_analysis.csv', index=False)
